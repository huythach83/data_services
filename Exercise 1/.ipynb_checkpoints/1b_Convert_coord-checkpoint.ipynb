# %%
import geopandas as gpd
# import pyproj
# from shapely.ops import transform

df = gpd.read_file('convert.shp')
df.head()
# Out:
#   STATEFP COUNTYFP       TLID      TFIDL      TFIDR  MTFCC     FULLNAME  SMID  \
# 0      51      740  122192450  217326600  217326601  S1400     Scott St  1604
# 1      51      740  122192498  217326599  217329859  S1400   Rodman Ave  1604
# 2      51      740  122199058  261427396  217326602  S1400      Race St  1604
# 3      51      740  122192438  217326603  217326635  S1400   Griffin St  1604
# 4      51      740  122192454  217326605  217326639  S1400  Loudoun Ave  1604
#
#   LFROMADD LTOADD  ...  TTYP DECKEDROAD ARTPATH PERSIST GCSEFLG OFFSETL  \
# 0     3401   3499  ...  None          N       N    None       N       N
# 1     1701   1799  ...  None          N       N    None       N       N
# 2     3501   3511  ...  None          N       N    None       N       N
# 3     3401   3499  ...  None          N       N    None       N       N
# 4     None   None  ...  None          N       N    None       N       N
#
#   OFFSETR     TNIDF     TNIDT  \
# ...

# %%
# Set the projection of the dataframe to GCS_WGS_1984 - Also known as EPSG:4326
df.crs = 'EPSG:4326'

# Covert the projection to NAD_1983_StatePlane_Virginia_South_FIPS_4502_Feet - Also known as ESRI:102747
df_convert = df.to_crs("ESRI:102747")

# %%
df_convert.head()
# Out:
#   STATEFP COUNTYFP       TLID      TFIDL      TFIDR  MTFCC     FULLNAME  SMID  \
# 0      51      740  122192450  217326600  217326601  S1400     Scott St  1604
# 1      51      740  122192498  217326599  217329859  S1400   Rodman Ave  1604
# 2      51      740  122199058  261427396  217326602  S1400      Race St  1604
# 3      51      740  122192438  217326603  217326635  S1400   Griffin St  1604
# 4      51      740  122192454  217326605  217326639  S1400  Loudoun Ave  1604
#
#   LFROMADD LTOADD  ...  TTYP DECKEDROAD ARTPATH PERSIST GCSEFLG OFFSETL  \
# 0     3401   3499  ...  None          N       N    None       N       N
# 1     1701   1799  ...  None          N       N    None       N       N
# 2     3501   3511  ...  None          N       N    None       N       N
# 3     3401   3499  ...  None          N       N    None       N       N
# 4     None   None  ...  None          N       N    None       N       N
#
#   OFFSETR     TNIDF     TNIDT  \
# ...

# %%
df_convert.to_file('convert_NAD.shp')
